# %%
# !pip install fasttext
# Out:
# Requirement already satisfied: fasttext in /opt/conda/lib/python3.10/site-packages (0.9.2)
# Requirement already satisfied: pybind11>=2.2 in /opt/conda/lib/python3.10/site-packages (from fasttext) (2.12.0)
# Requirement already satisfied: setuptools>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from fasttext) (69.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from fasttext) (1.26.4)

# %% [markdown]
# # libraries

# %%
import pandas as pd
from gensim.models.fasttext import FastText
import fasttext.util
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %% [markdown]
# # Load Data

# %%
tips = pd.read_json("/kaggle/input/yelp-dataset/yelp_academic_dataset_tip.json", lines=True)
tips_text = tips['text'].tolist()
subset_tips = tips_text[:1000]

# %% [markdown]
# # Preprocessing

# %%
def preprocess(text):
    # Tokenization
    tokens = word_tokenize(text)

    # Lowercasing
    tokens = [token.lower() for token in tokens]

    # Remove punctuation
    tokens = [re.sub(r'[^a-zA-Z\s]', ' ', token) for token in tokens]

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words and len(token) > 3]

    # Stemming
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Reconstruct the text
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
import nltk
import subprocess
try:
    nltk.data.find('wordnet.zip')
except:
    nltk.download('wordnet', download_dir='/kaggle/working/')
    command = "unzip /kaggle/working/corpora/wordnet.zip -d /kaggle/working/corpora"
    subprocess.run(command.split())
    nltk.data.path.append('/kaggle/working/')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package wordnet to /kaggle/working/...
# [nltk_data]   Package wordnet is already up-to-date!
# Archive:  /kaggle/working/corpora/wordnet.zip
# replace /kaggle/working/corpora/wordnet/lexnames? [y]es, [n]o, [A]ll, [N]one, [r]ename:  NULL
# (EOF or read error, treating as "[N]one" ...)

# %%
tips_preprocessed = []

for text in subset_tips:
    preprocessed_text = preprocess(text)
    tokens = word_tokenize(preprocessed_text)
    tips_preprocessed.append(tokens)

# %%
# model = FastText(vector_size=100, window=5, min_count=5)
# model.build_vocab(corpus_iterable=tips_preprocessed)
# model.train(corpus_iterable=tips_preprocessed, total_examples=len(tips_preprocessed), epochs=10)
# def test(embedding, word):
#     try:
#         similar_words = embedding.wv.most_similar(word)
#         negative_words = embedding.wv.most_similar(negative=[word],topn=10)
#         return similar_words, negative_words
#     except KeyError:
#         return None, None

# %% [markdown]
# # Custom_Fasttext

# %%
def train_Fasttext(sentences,embedding_size,window_size,min_word,down_sampling,Save_model_filename):
    fast_Text_model = FastText(sentences,
    vector_size=embedding_size, 
    window=window_size,
    min_count=min_word, 
    sample=down_sampling, 
    workers = 4, 
    sg=1, 
    epochs=100) 

    fast_Text_model.save(Save_model_filename)

# %%
embedding_size = 300
window_size = 5
min_word = 5
down_sampling = 1e-2

train_Fasttext(tips_preprocessed,embedding_size,window_size,min_word,down_sampling,"Custom_FastText")

# %%
from gensim.models import Word2Vec

# %%
fast_Text_model = Word2Vec.load("/kaggle/working/Custom_FastText")

# %%
! wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
! gunzip "cc.en.300.bin.gz"
# Out:
# --2024-04-21 07:22:09--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.7.128, 13.35.7.38, 13.35.7.82, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.7.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4503593528 (4.2G) [application/octet-stream]
# Saving to: 'cc.en.300.bin.gz'
#
# cc.en.300.bin.gz      9%[>                   ] 393.96M  88.0MB/s    eta 50s    ^C
# gzip: cc.en.300.bin already exists; do you wish to overwrite (y or n)? ^C

# %%
from gensim.models.fasttext import load_facebook_model

ft=load_facebook_model('/kaggle/working/cc.en.300.bin')

# %%
from tabulate import tabulate
words = list(fast_Text_model.wv.key_to_index)  

for i in range(len(words)):
    if i % 10 == 0: 
        print(f"Analyzing word: {words[i]}\n")
        
        
        similar_words_custom = fast_Text_model.wv.most_similar(words[i], topn=10)
        opposite_words_custom = fast_Text_model.wv.most_similar(negative=[words[i]], topn=10)
        similar_words_pretrained = ft.wv.most_similar(words[i], topn=10)
        opposite_words_pretrained = ft.wv.most_similar(negative=[words[i]], topn=10)
        print("Custom-trained FastText model results:")
        table_custom_similar = tabulate(similar_words_custom, headers=['Similar Word', 'Similarity'], tablefmt='github')
        table_custom_opposite = tabulate(opposite_words_custom, headers=['Opposite Word', 'Similarity'], tablefmt='github')
        table_pretrained_similar = tabulate(similar_words_pretrained, headers=['Similar Word', 'Similarity'], tablefmt='github')
        table_pretrained_opposite = tabulate(opposite_words_pretrained, headers=['Opposite Word', 'Similarity'], tablefmt='github')
        
        # Printing the tables
        print("Top 10 similar words (custom model):")
        print(table_custom_similar)
        print("\nTop 10 opposite words (custom model):")
        print(table_custom_opposite)
        print("\nTop 10 similar words (pre-trained model):")
        print(table_pretrained_similar)
        print("\nTop 10 opposite words (pre-trained model):")
        print(table_pretrained_opposite)
        print("\n" + "-"*40 + "\n")  # Separator for readability
# Out:
# Analyzing word: great
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | eat            |     0.469364 |
# | lot            |     0.45095  |
# | highli         |     0.44481  |
# | favorit        |     0.441522 |
# | choic          |     0.433028 |
# | pickl          |     0.415312 |
# | fantast        |     0.410896 |
# | server         |     0.390318 |
# | burrito        |     0.387188 |
# | breakfast      |     0.385408 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | would           |   0.0539012  |
# | check           |   0.0418079  |
# | hand            |   0.0330255  |
# | store           |   0.0326116  |
# | yelp            |  -0.00583709 |
# | sign            |  -0.0205808  |
# | keep            |  -0.0224004  |
# | next            |  -0.0244066  |
# | go              |  -0.0322912  |
# | late            |  -0.0329636  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | fantastic      |     0.803248 |
# | terrific       |     0.794706 |
# | wonderful      |     0.745393 |
# | good           |     0.74261  |
# | geat           |     0.740687 |
# | excellent      |     0.708568 |
# | amazing        |     0.691058 |
# | tremendous     |     0.687774 |
# | nice           |     0.680214 |
# | awesome        |     0.678551 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | 18304           |     0.212666 |
# | 22128           |     0.209146 |
# | law.7.          |     0.204089 |
# | 15608           |     0.201779 |
# | 0919            |     0.201515 |
# | 1993â           |     0.199587 |
# | .3.3            |     0.198747 |
# | title17         |     0.19677  |
# | 11604           |     0.196546 |
# | AETR            |     0.196204 |
#
# ----------------------------------------
#
# Analyzing word: like
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | around         |     0.502157 |
# | find           |     0.457234 |
# | garlic         |     0.451317 |
# | huge           |     0.431589 |
# | know           |     0.408848 |
# | miss           |     0.402563 |
# | littl          |     0.402514 |
# | could          |     0.401335 |
# | use            |     0.39398  |
# | look           |     0.393641 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | wednesday       |   0.124218   |
# | margarita       |   0.0195532  |
# | first           |   0.0126325  |
# | fish            |   0.00615859 |
# | atmospher       |  -0.00305203 |
# | server          |  -0.0042918  |
# | meal            |  -0.00641625 |
# | serv            |  -0.0186131  |
# | wine            |  -0.0269245  |
# | fantast         |  -0.0297214  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | lke            |     0.707831 |
# | llike          |     0.69981  |
# | think          |     0.667807 |
# | lilke          |     0.65689  |
# | just           |     0.630159 |
# | liek           |     0.620903 |
# | really         |     0.613028 |
# | feel           |     0.608207 |
# | something      |     0.604177 |
# | want           |     0.600882 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | EHAC            |     0.231001 |
# | LocationPrivate |     0.215215 |
# | StoriesRelated  |     0.207825 |
# | 1al             |     0.202048 |
# | Decem-          |     0.199976 |
# | IndustryTop     |     0.198232 |
# | ContentAbout    |     0.196136 |
# | Opslag          |     0.195956 |
# | report11        |     0.195425 |
# | production6     |     0.194262 |
#
# ----------------------------------------
#
# Analyzing word: take
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | ahead          |     0.49863  |
# | find           |     0.489124 |
# | long           |     0.486627 |
# | call           |     0.483181 |
# | card           |     0.4703   |
# | sweet          |     0.466306 |
# | made           |     0.453129 |
# | prepar         |     0.449813 |
# | el             |     0.445026 |
# | line           |     0.442923 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | better          |    0.0458014 |
# | item            |    0.0435471 |
# | excel           |    0.0345604 |
# | plu             |    0.0292007 |
# | pizza           |    0.0232215 |
# | favorit         |    0.0139312 |
# | garlic          |    0.0134931 |
# | store           |    0.0129901 |
# | drink           |    0.0115393 |
# | local           |   -0.0161322 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | taking         |     0.734091 |
# | takes          |     0.702726 |
# | took           |     0.675042 |
# | Take           |     0.656478 |
# | taken          |     0.642321 |
# | Taking         |     0.637818 |
# | give           |     0.609153 |
# | get            |     0.592546 |
# | tkae           |     0.577259 |
# | put            |     0.569382 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Eccrine         |     0.253597 |
# | Filamentary     |     0.227131 |
# | ED9             |     0.22342  |
# | HLA-DPB1        |     0.211123 |
# | 19845           |     0.210551 |
# | .Speciality     |     0.210454 |
# | HLA-C           |     0.207932 |
# | EDRegion        |     0.206514 |
# | 19298           |     0.206218 |
# | 2016-07         |     0.205141 |
#
# ----------------------------------------
#
# Analyzing word: close
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | thursday       |     0.593809 |
# | bottl          |     0.593331 |
# | open           |     0.572079 |
# | pitcher        |     0.569925 |
# | actual         |     0.557212 |
# | saturday       |     0.552258 |
# | sunday         |     0.549342 |
# | pack           |     0.545945 |
# | margarita      |     0.541204 |
# | event          |     0.540102 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | portion         |  0.0448034   |
# | larg            |  0.0280393   |
# | sandwich        |  0.0126226   |
# | steak           |  0.0105812   |
# | onion           |  0.0101733   |
# | item            |  0.00472221  |
# | best            | -0.000980936 |
# | find            | -0.00249025  |
# | option          | -0.0134295   |
# | section         | -0.019564    |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | proximity      |     0.629862 |
# | closer         |     0.616403 |
# | super-close    |     0.610452 |
# | clsoe          |     0.596993 |
# | not-so-close   |     0.591952 |
# | semi-close     |     0.586722 |
# | closest        |     0.566755 |
# | Close          |     0.561091 |
# | near           |     0.552674 |
# | closee         |     0.540328 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word       |   Similarity |
# |---------------------|--------------|
# | .METHODS            |     0.236862 |
# | -treatment          |     0.234361 |
# | Adjuvants           |     0.234151 |
# | ExperienceDigital   |     0.23055  |
# | strategiesSub-Topic |     0.224643 |
# | sub06               |     0.222676 |
# | MoreClass           |     0.220427 |
# | OfficerMr           |     0.220413 |
# | Ersatz              |     0.220063 |
# | Blap                |     0.218969 |
#
# ----------------------------------------
#
# Analyzing word: salad
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | soup           |     0.600582 |
# | portion        |     0.559649 |
# | crispi         |     0.516038 |
# | chicken        |     0.483115 |
# | littl          |     0.482063 |
# | roll           |     0.481486 |
# | excel          |     0.476198 |
# | spring         |     0.467204 |
# | shrimp         |     0.465144 |
# | thai           |     0.462405 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | custom          |   0.0683532  |
# | open            |   0.0474768  |
# | want            |   0.0104745  |
# | could           |   0.00918752 |
# | owner           |   0.00230973 |
# | time            |  -0.00251918 |
# | went            |  -0.0122893  |
# | work            |  -0.0123052  |
# | cool            |  -0.01268    |
# | flavor          |  -0.0148414  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | salads         |     0.803952 |
# | salad-         |     0.797607 |
# | salad.I        |     0.777328 |
# | salad.         |     0.746637 |
# | salad.The      |     0.743284 |
# | salad.This     |     0.730194 |
# | vinaigrette    |     0.723386 |
# | Salad          |     0.721476 |
# | coleslaw       |     0.70476  |
# | vinegarette    |     0.701061 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Gráficos        |     0.215602 |
# | Examrace        |     0.168899 |
# | Vistakon        |     0.167026 |
# | RatingClass     |     0.165264 |
# | Bodhtree        |     0.163952 |
# | 19955           |     0.163436 |
# | DetailsNational |     0.163082 |
# | Experteer       |     0.162926 |
# | Aderyn          |     0.162802 |
# | SideFX          |     0.160775 |
#
# ----------------------------------------
#
# Analyzing word: better
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | shop           |     0.575205 |
# | yogurt         |     0.517277 |
# | frozen         |     0.512128 |
# | look           |     0.500099 |
# | white          |     0.473142 |
# | feel           |     0.471574 |
# | offic          |     0.465751 |
# | step           |     0.450383 |
# | highli         |     0.4486   |
# | snack          |     0.444746 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | take            |    0.0458014 |
# | area            |    0.0444699 |
# | make            |   -0.0205269 |
# | side            |   -0.0327385 |
# | head            |   -0.0327867 |
# | anyth           |   -0.0398637 |
# | time            |   -0.051445  |
# | bring           |   -0.0516805 |
# | keep            |   -0.0540564 |
# | fish            |   -0.0636381 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | bettter        |     0.818785 |
# | beter          |     0.720786 |
# | worse          |     0.701799 |
# | nicer          |     0.690544 |
# | smarter        |     0.654122 |
# | bettere        |     0.643556 |
# | BETTER         |     0.636937 |
# | clearer        |     0.632646 |
# | MUCH           |     0.628144 |
# | better.So      |     0.625478 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word        |   Similarity |
# |----------------------|--------------|
# | 17Duration           |     0.245894 |
# | February-1           |     0.227557 |
# | EHAC                 |     0.220724 |
# | 20211                |     0.220703 |
# | CharacteristicsColor |     0.217826 |
# | Reprintas            |     0.217552 |
# | CompanyTel           |     0.214905 |
# | 201623               |     0.214511 |
# | 1919-1938            |     0.213423 |
# | YearsMinimal         |     0.20904  |
#
# ----------------------------------------
#
# Analyzing word: today
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | still          |     0.635107 |
# | took           |     0.599952 |
# | fill           |     0.54622  |
# | bring          |     0.536098 |
# | sunday         |     0.500345 |
# | friday         |     0.482271 |
# | monday         |     0.474067 |
# | thursday       |     0.462883 |
# | loud           |     0.458115 |
# | head           |     0.448137 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | choic           |   0.0656657  |
# | menu            |   0.0642242  |
# | wine            |   0.0235705  |
# | amaz            |   0.0151143  |
# | select          |  -0.00254018 |
# | green           |  -0.0165759  |
# | pizza           |  -0.0250032  |
# | larg            |  -0.0258945  |
# | littl           |  -0.0284092  |
# | friendli        |  -0.0307187  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | Today          |     0.701003 |
# | yesterday      |     0.682308 |
# | tomorrow       |     0.679118 |
# | today.This     |     0.633309 |
# | today.It       |     0.63324  |
# | today.Now      |     0.623106 |
# | today.But      |     0.621447 |
# | today.So       |     0.620653 |
# | today.Today    |     0.620008 |
# | today-and      |     0.60403  |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word        |   Similarity |
# |----------------------|--------------|
# | RegulationsPrecision |     0.249277 |
# | -cap                 |     0.241477 |
# | MKK4                 |     0.227012 |
# | Made-for-television  |     0.226654 |
# | Renilla              |     0.225107 |
# | FamilyCustomized     |     0.22207  |
# | ReferencesLimiting   |     0.221525 |
# | gWidth156            |     0.220522 |
# | FamilyCustom         |     0.219546 |
# | DirectionsPrepare    |     0.218608 |
#
# ----------------------------------------
#
# Analyzing word: wing
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | wine           |     0.58331  |
# | bring          |     0.522915 |
# | garlic         |     0.51685  |
# | spring         |     0.506075 |
# | slow           |     0.489046 |
# | feel           |     0.48787  |
# | event          |     0.48142  |
# | flavor         |     0.474289 |
# | brunch         |     0.455249 |
# | thing          |     0.449231 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | made            |   0.00398492 |
# | staff           |  -0.00508712 |
# | time            |  -0.0124398  |
# | friendli        |  -0.0241779  |
# | cream           |  -0.0287918  |
# | take            |  -0.0349902  |
# | need            |  -0.0355805  |
# | menu            |  -0.0375685  |
# | delici          |  -0.0480996  |
# | clean           |  -0.0490807  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | wing.The       |     0.71861  |
# | wing.          |     0.712444 |
# | wing-          |     0.684052 |
# | wings          |     0.66607  |
# | wing.I         |     0.63843  |
# | -wing          |     0.585452 |
# | Wing           |     0.576934 |
# | wingers        |     0.573484 |
# | fuselage       |     0.546178 |
# | mid-wing       |     0.545121 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word        |   Similarity |
# |----------------------|--------------|
# | moreHave             |     0.207186 |
# | PURCHASING           |     0.206403 |
# | BizBen               |     0.201364 |
# | index.form.searching |     0.201147 |
# | UncommonGoods        |     0.19853  |
# | e-Cycle              |     0.197365 |
# | LocalBitcoins        |     0.196481 |
# | more.10              |     0.193237 |
# | MoreWin              |     0.193182 |
# | ecoATM               |     0.189783 |
#
# ----------------------------------------
#
# Analyzing word: taco
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | burrito        |     0.726509 |
# | thursday       |     0.718781 |
# | start          |     0.666829 |
# | shrimp         |     0.660323 |
# | chip           |     0.634752 |
# | fish           |     0.630401 |
# | beef           |     0.626861 |
# | white          |     0.580243 |
# | beer           |     0.5673   |
# | roll           |     0.561918 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | pick            |    0.077889  |
# | keep            |    0.0565015 |
# | need            |    0.0277454 |
# | give            |   -0.0268709 |
# | section         |   -0.030879  |
# | card            |   -0.0312235 |
# | watch           |   -0.0478638 |
# | small           |   -0.0531552 |
# | quick           |   -0.0557048 |
# | loud            |   -0.0639667 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | tacos          |     0.82135  |
# | burrito        |     0.729793 |
# | fajita         |     0.71744  |
# | taquito        |     0.699254 |
# | tostada        |     0.676348 |
# | Taco           |     0.674844 |
# | burritos       |     0.666288 |
# | buritto        |     0.663018 |
# | carnita        |     0.662221 |
# | tostadas       |     0.660193 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Haemophilia     |     0.232696 |
# | Keightley       |     0.205252 |
# | Marie-Adélaïde  |     0.204434 |
# | Ormonde         |     0.201893 |
# | Saxe-Gotha      |     0.197959 |
# | Malfroy         |     0.191202 |
# | NetSys          |     0.190506 |
# | Wyper           |     0.190001 |
# | Kemei           |     0.188772 |
# | Valland         |     0.188278 |
#
# ----------------------------------------
#
# Analyzing word: also
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | breakfast      |     0.570296 |
# | pickl          |     0.554361 |
# | peopl          |     0.543132 |
# | noodl          |     0.500864 |
# | choic          |     0.499681 |
# | fast           |     0.495329 |
# | keep           |     0.474559 |
# | chili          |     0.439715 |
# | must           |     0.432864 |
# | alway          |     0.43281  |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | special         |  0.00442518  |
# | crowd           |  0.00309236  |
# | would           |  0.00228668  |
# | dinner          |  0.000171105 |
# | atmospher       | -0.000325014 |
# | le              | -0.0121317   |
# | night           | -0.0134649   |
# | come            | -0.0234492   |
# | pack            | -0.0250774   |
# | went            | -0.0384887   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | alos           |     0.612729 |
# | aslo           |     0.604044 |
# | additionally   |     0.602794 |
# | likewise       |     0.601081 |
# | may            |     0.595232 |
# | which          |     0.594681 |
# | have           |     0.581044 |
# | always         |     0.576914 |
# | certainly      |     0.574309 |
# | has            |     0.571124 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | by7             |     0.25102  |
# | by3             |     0.245488 |
# | by2             |     0.240308 |
# | by4             |     0.23649  |
# | title20         |     0.236144 |
# | title10         |     0.231882 |
# | one8            |     0.227036 |
# | title14         |     0.222865 |
# | by6             |     0.221155 |
# | title16         |     0.219596 |
#
# ----------------------------------------
#
# Analyzing word: music
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | patio          |     0.629199 |
# | live           |     0.608296 |
# | loud           |     0.58574  |
# | head           |     0.580975 |
# | drink          |     0.54301  |
# | super          |     0.536692 |
# | cheap          |     0.531608 |
# | atmospher      |     0.520702 |
# | style          |     0.511981 |
# | actual         |     0.494628 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | full            |   0.0201903  |
# | yummi           |   0.00726651 |
# | hand            |  -0.0132031  |
# | lunch           |  -0.0141187  |
# | tast            |  -0.0175828  |
# | dinner          |  -0.0250179  |
# | earli           |  -0.0305611  |
# | last            |  -0.0432657  |
# | time            |  -0.0464138  |
# | best            |  -0.0772811  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | musics         |     0.722612 |
# | muisc          |     0.706863 |
# | music.This     |     0.705993 |
# | music.         |     0.703124 |
# | music.The      |     0.695549 |
# | music.It       |     0.690009 |
# | music.But      |     0.682865 |
# | music.Music    |     0.677197 |
# | music-         |     0.669787 |
# | music.Now      |     0.665351 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | P-17            |     0.19619  |
# | 2013.5          |     0.185686 |
# | 194.40          |     0.184938 |
# | 141.10          |     0.184308 |
# | Releasable      |     0.181041 |
# | 230.95          |     0.180723 |
# | permalinkTom    |     0.179913 |
# | L144            |     0.17953  |
# | 202.50          |     0.178859 |
# | Limus           |     0.177918 |
#
# ----------------------------------------
#
# Analyzing word: find
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | fill           |     0.657154 |
# | still          |     0.583091 |
# | crispi         |     0.576936 |
# | around         |     0.574719 |
# | huge           |     0.565113 |
# | cash           |     0.562798 |
# | spici          |     0.546348 |
# | prepar         |     0.499014 |
# | beauti         |     0.496284 |
# | thing          |     0.493662 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | margarita       |   0.0905423  |
# | breakfast       |   0.0146081  |
# | fast            |   0.0138566  |
# | wine            |   0.0130066  |
# | close           |  -0.00249025 |
# | select          |  -0.0059728  |
# | bottl           |  -0.0173902  |
# | clean           |  -0.0240771  |
# | burrito         |  -0.0258874  |
# | food            |  -0.0440961  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | discover       |     0.706403 |
# | locate         |     0.701587 |
# | finding        |     0.651792 |
# | found          |     0.620514 |
# | searching      |     0.611883 |
# | try            |     0.608685 |
# | see            |     0.607518 |
# | uncover        |     0.601579 |
# | can            |     0.597782 |
# | help           |     0.582271 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word     |   Similarity |
# |-------------------|--------------|
# | Politics3         |     0.22513  |
# | 2006-2015         |     0.212125 |
# | States6           |     0.211378 |
# | 11National        |     0.209436 |
# | Women29th         |     0.207808 |
# | Politics2         |     0.207187 |
# | advice.Disclaimer |     0.207133 |
# | .Acute            |     0.202872 |
# | Security1         |     0.201804 |
# | Hemorrhagic       |     0.198818 |
#
# ----------------------------------------
#
# Analyzing word: fish
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | chip           |     0.700609 |
# | taco           |     0.630401 |
# | burrito        |     0.539889 |
# | wish           |     0.533492 |
# | thursday       |     0.51928  |
# | el             |     0.509891 |
# | anyth          |     0.507157 |
# | rice           |     0.49866  |
# | year           |     0.496721 |
# | bean           |     0.48973  |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | littl           |   0.105612   |
# | snack           |   0.00622948 |
# | like            |   0.00615859 |
# | back            |   0.00189373 |
# | pick            |  -0.00488956 |
# | pizza           |  -0.0291636  |
# | food            |  -0.0313144  |
# | section         |  -0.0318884  |
# | cool            |  -0.0389232  |
# | quick           |  -0.044262   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | fishes         |     0.788581 |
# | fish.The       |     0.733277 |
# | fish.But       |     0.732131 |
# | fish.It        |     0.727441 |
# | fish-          |     0.726637 |
# | fish.I         |     0.720879 |
# | fish.This      |     0.713171 |
# | trout          |     0.710777 |
# | fish.So        |     0.707072 |
# | catfish        |     0.702544 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word      |   Similarity |
# |--------------------|--------------|
# | DriveTime          |     0.220722 |
# | TORR               |     0.216178 |
# | PRT                |     0.212831 |
# | Imperio            |     0.206117 |
# | Shwayder           |     0.186153 |
# | 22031              |     0.185188 |
# | SVAC               |     0.182606 |
# | BlackHairMedia.com |     0.178696 |
# | Azadi              |     0.178068 |
# | Principa           |     0.177931 |
#
# ----------------------------------------
#
# Analyzing word: style
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | italian        |     0.576951 |
# | dessert        |     0.537178 |
# | give           |     0.534252 |
# | famili         |     0.524139 |
# | rice           |     0.5226   |
# | cuban          |     0.51604  |
# | authent        |     0.514623 |
# | music          |     0.511981 |
# | home           |     0.507282 |
# | atmospher      |     0.506732 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | park            |   0.0685168  |
# | larg            |   0.0478034  |
# | wait            |   0.0408493  |
# | long            |   0.0281364  |
# | worth           |   0.00436464 |
# | visit           |   0.00273522 |
# | next            |  -0.0177028  |
# | right           |  -0.0228035  |
# | self            |  -0.0314141  |
# | serv            |  -0.0327328  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | syle           |     0.76577  |
# | stlye          |     0.706423 |
# | sytle          |     0.706278 |
# | styles         |     0.697495 |
# | style.What     |     0.673087 |
# | style.The      |     0.668243 |
# | style.         |     0.654562 |
# | style.This     |     0.647952 |
# | style.It       |     0.639992 |
# | style.When     |     0.625744 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word    |   Similarity |
# |------------------|--------------|
# | 2017Yesterday    |     0.251064 |
# | NewsTarget       |     0.223847 |
# | NaturalHealth365 |     0.219847 |
# | WHTM             |     0.214307 |
# | pointsMajor      |     0.204973 |
# | 2016Earth        |     0.204934 |
# | JustBe           |     0.20408  |
# | ill.In           |     0.2039   |
# | cooldownPlaces   |     0.203331 |
# | 11National       |     0.201841 |
#
# ----------------------------------------
#
# Analyzing word: pickl
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | noodl          |     0.706309 |
# | seafood        |     0.683034 |
# | portion        |     0.668587 |
# | fri            |     0.649783 |
# | onion          |     0.642816 |
# | enjoy          |     0.636035 |
# | soup           |     0.630697 |
# | pepper         |     0.614942 |
# | peopl          |     0.605406 |
# | season         |     0.591605 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | event           | -3.21446e-05 |
# | come            | -0.00422108  |
# | yelp            | -0.0216474   |
# | deal            | -0.0227884   |
# | pack            | -0.0251587   |
# | sunday          | -0.027648    |
# | use             | -0.0287908   |
# | would           | -0.032362    |
# | burger          | -0.0446675   |
# | hour            | -0.0446732   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |   Similarity |
# |------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------|
# | airplanealertapp-downloadarrow-downarrow-expandarrow-leftarrow-right-alternatearrow-rightarrow-upattractionbadgeballoonsbarcodebellbookbuildingcalendarcameracarcartcash-backchairchat-dotschatcheck-circlecheckboxclosecomputercreatecruiseemptybadgeenvelope-open-outlineenvelope-openenvelopefacebookfingerflowerfoodfootballgeargift-cardgiftgridguitarhealthheart-outlinehearthome-gardeninfojewellifetime-cashbacklipsticklocationlockmapmedalmenuminus-circlemoneynewsomnichannelpacifierpaperclippawphoneplayplugplusprintpromotedquestion-markrebatermn-rsearchshareshirtshoeslidersstar-outlinestarstopwatchstoretag-addtagthumbs-downthumbs-uptoytrophyuserwatchx |     0.548149 |
# | love-in-paris-soha-ali-khan-kunal-khemu-get-engaged-in-the-city-of-love                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |     0.538161 |
# | RoverLexusLincolnLotusMaseratiMazdaMcLarenMercedes-BenzMINIMitsubishiNissanPorscheRAMRolls-RoycesmartSubaruTeslaToyotaVolkswagenVolvoModelYear                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |     0.530454 |
# |                                                                                                                                                                                                                                                                                                             |     0.524828 |
# |                                                                                                                                                                                                                                                                                                             |     0.51926  |
# | RoverLexusLincolnLotusMaseratiMazdaMcLarenMercedes-BenzMINIMitsubishiNissanPorscheRAMRolls-RoycesmartSubaruTeslaToyotaVolkswagenVolvo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |     0.511576 |
# | ZJiUJNWmL69qHRgQACH5BAkKAAQALAkAAAAQABIAAAhnAAEQGEiwoEEBAAQaJJBQIQEBEB0OBDCgokKIEQlSrDjgIkaHGy0OxJiRIUeHHxFqFDkxYUSFDROOJBmTo0iEHxva7Mgwp86dAGjGDMnzY0uiRWVqRCpQ4lKgCydCjWrSplODQwcGBAAh                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |     0.5114   |
# | crescendosexibloguerobateyabsorbersexiindesignabledinerolatifundiosexibrezarcularsutesexirapoplinbrezarcorrentosoVd.lazadareflejoreglafeministabrezarchuzasexiouttiqueblogueroin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |     0.503989 |
# | 81-post-18-free-service-invoice-templates-in-word-and-excel-hloomcom-cool-math-gamesus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |     0.500695 |
# | atomiumdiscdjeuropaheadphonesinkmahjongmusicpeaceandloveradioshouttechnotigertonyvinylewarningyinyangGraffiti                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |     0.499103 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | 􀁷               |     0.38219  |
# | 􀁱               |     0.380143 |
# | ãŽã             |     0.368204 |
# | 􀁀               |     0.344517 |
# | 9ห              |     0.339465 |
# | 􀁨               |     0.328021 |
# |                |     0.324715 |
# | नवम             |     0.320063 |
# | 16ห             |     0.311832 |
# | 􀁜               |     0.308551 |
#
# ----------------------------------------
#
# Analyzing word: noth
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | loud           |     0.593641 |
# | crowd          |     0.562069 |
# | special        |     0.526617 |
# | tasti          |     0.520017 |
# | patio          |     0.514798 |
# | favorit        |     0.512415 |
# | m              |     0.506304 |
# | spici          |     0.497907 |
# | drink          |     0.494536 |
# | kid            |     0.482163 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | servic          |   0.0346473  |
# | offic           |   0.0288101  |
# | show            |   0.00846669 |
# | serv            |  -0.0124406  |
# | best            |  -0.0200758  |
# | everi           |  -0.0293981  |
# | charg           |  -0.0308915  |
# | salad           |  -0.0332529  |
# | experi          |  -0.047025   |
# | shop            |  -0.0566644  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | noth-          |     0.582944 |
# | nothi          |     0.573756 |
# | ther           |     0.565285 |
# | nore           |     0.565032 |
# | ing            |     0.563523 |
# | excep          |     0.560629 |
# | nev            |     0.53327  |
# | anyt           |     0.523654 |
# | anoth          |     0.521069 |
# | whate          |     0.509123 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word       |   Similarity |
# |---------------------|--------------|
# | CSAS                |     0.208824 |
# | Energetics          |     0.176864 |
# | Viewpoints          |     0.176549 |
# | Motifs              |     0.174342 |
# | VectorVest          |     0.170786 |
# | AfterDark           |     0.168096 |
# | ResourcesLinks      |     0.167942 |
# | .Curated2           |     0.167462 |
# | Heart-to-Heart      |     0.166357 |
# | SpectroscopyAuthors |     0.166093 |
#
# ----------------------------------------
#
# Analyzing word: margarita
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | pitcher        |     0.733715 |
# | bottl          |     0.685427 |
# | actual         |     0.662139 |
# | thursday       |     0.627392 |
# | super          |     0.623972 |
# | m              |     0.578202 |
# | monday         |     0.556549 |
# | wednesday      |     0.545065 |
# | close          |     0.541204 |
# | tri            |     0.540022 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | around          |   0.123442   |
# | find            |   0.0905423  |
# | fill            |   0.0648587  |
# | like            |   0.0195532  |
# | thing           |   0.0174198  |
# | prepar          |   0.00351051 |
# | bread           |  -0.00687338 |
# | much            |  -0.0146585  |
# | still           |  -0.0195161  |
# | sandwich        |  -0.0229292  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | margaritas     |     0.825547 |
# | mojito         |     0.751122 |
# | margs          |     0.750513 |
# | daiquiri       |     0.721273 |
# | michelada      |     0.71399  |
# | sangria        |     0.710345 |
# | tequila        |     0.70979  |
# | Margaritas     |     0.702182 |
# | martini        |     0.701805 |
# | daquiri        |     0.696102 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Haringey        |     0.204858 |
# | Ofsted          |     0.200253 |
# | Churchdown      |     0.198582 |
# | Coverts         |     0.198232 |
# | Mid-Kent        |     0.193817 |
# | GL9             |     0.192865 |
# | Aimhigher       |     0.191268 |
# | ChinaMore       |     0.189469 |
# | ExCel           |     0.189027 |
# | Kindertransport |     0.188438 |
#
# ----------------------------------------
#
# Analyzing word: went
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | tri            |     0.648643 |
# | serv           |     0.584249 |
# | friend         |     0.565576 |
# | could          |     0.546407 |
# | worst          |     0.544284 |
# | server         |     0.542547 |
# | appet          |     0.528856 |
# | actual         |     0.526983 |
# | miss           |     0.521356 |
# | authent        |     0.520389 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | bread           |  0.0836539   |
# | option          |  0.0211252   |
# | alway           |  0.00922603  |
# | breakfast       |  0.00453157  |
# | brunch          |  0.00372298  |
# | brew            | -0.000106743 |
# | rice            | -0.00577141  |
# | salad           | -0.0122893   |
# | park            | -0.0190952   |
# | plu             | -0.0244053   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | came           |     0.80588  |
# | proceeded      |     0.689529 |
# | ran            |     0.688486 |
# | drove          |     0.685829 |
# | walked         |     0.667356 |
# | took           |     0.659802 |
# | Went           |     0.657179 |
# | started        |     0.650474 |
# | got            |     0.647704 |
# | turned         |     0.647503 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | properties1     |     0.240167 |
# | ContentsNote    |     0.219754 |
# | statement.Ideas |     0.218234 |
# | 1Construction   |     0.217258 |
# | spaceMay        |     0.212553 |
# | Immunogenic     |     0.212349 |
# | awardDistrict   |     0.211333 |
# | CLIMATEThe      |     0.210289 |
# | data11          |     0.209364 |
# | future.Related  |     0.205048 |
#
# ----------------------------------------
#
# Analyzing word: server
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | serv           |     0.698737 |
# | slow           |     0.687032 |
# | servic         |     0.629353 |
# | pitcher        |     0.621767 |
# | took           |     0.618024 |
# | meal           |     0.611683 |
# | thursday       |     0.602577 |
# | minut          |     0.593039 |
# | driver         |     0.574563 |
# | appet          |     0.556096 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | full            |   0.0419855  |
# | cake            |   0.00880637 |
# | like            |  -0.0042918  |
# | rice            |  -0.0149172  |
# | bean            |  -0.0166885  |
# | snack           |  -0.017415   |
# | roll            |  -0.0233189  |
# | option          |  -0.0401823  |
# | week            |  -0.0497893  |
# | must            |  -0.0620356  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | servers        |     0.837433 |
# | server.The     |     0.74168  |
# | server.So      |     0.728377 |
# | server.If      |     0.717528 |
# | server.        |     0.707604 |
# | server.A       |     0.702985 |
# | server.But     |     0.699531 |
# | server.I       |     0.691981 |
# | server.When    |     0.690372 |
# | webserver      |     0.681281 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word        |   Similarity |
# |----------------------|--------------|
# | California--Los      |     0.222944 |
# | 2017Ways             |     0.20393  |
# | Raup                 |     0.202864 |
# | Topicseditorialsjack |     0.192831 |
# | CommentsKids         |     0.19096  |
# | M.A.P.               |     0.190275 |
# | ExercisesBitzer      |     0.188495 |
# | Nelson2              |     0.188252 |
# | Barnas               |     0.187264 |
# | Dicky                |     0.185224 |
#
# ----------------------------------------
#
# Analyzing word: cold
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | steak          |     0.574887 |
# | roll           |     0.572242 |
# | fri            |     0.536598 |
# | fantast        |     0.503766 |
# | cuban          |     0.503756 |
# | shop           |     0.467668 |
# | shrimp         |     0.467068 |
# | friday         |     0.466751 |
# | fast           |     0.461163 |
# | week           |     0.459348 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | el              |   0.0783721  |
# | stop            |   0.0696568  |
# | watch           |   0.0142454  |
# | chili           |   0.00478448 |
# | busi            |   0.00245503 |
# | game            |  -0.0284679  |
# | sign            |  -0.0386685  |
# | ahead           |  -0.0634833  |
# | menu            |  -0.0662919  |
# | prepar          |  -0.0700198  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | chilly         |     0.746299 |
# | semi-cold      |     0.699524 |
# | frigid         |     0.695505 |
# | cold-          |     0.691655 |
# | coldish        |     0.673397 |
# | cold-ish       |     0.672181 |
# | colder         |     0.665964 |
# | warm           |     0.662612 |
# | frosty         |     0.658192 |
# | cold.But       |     0.657435 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | LTRC            |     0.214706 |
# | Orteza          |     0.213646 |
# | Anos            |     0.211945 |
# | GroupSpaces     |     0.208546 |
# | Certeza         |     0.205821 |
# | AMEND           |     0.205813 |
# | TBTA            |     0.201972 |
# | 253a            |     0.200349 |
# | BARUCH          |     0.200253 |
# | Bookshare.org   |     0.198668 |
#
# ----------------------------------------
#
# Analyzing word: steak
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | week           |     0.593959 |
# | italian        |     0.591072 |
# | cold           |     0.574887 |
# | sandwich       |     0.572649 |
# | pickl          |     0.571987 |
# | bread          |     0.554383 |
# | season         |     0.548112 |
# | taco           |     0.539991 |
# | fri            |     0.521549 |
# | sweet          |     0.513374 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | quick           |   0.0969304  |
# | free            |   0.022245   |
# | even            |   0.0197438  |
# | close           |   0.0105812  |
# | food            |   0.00828995 |
# | loud            |  -0.0197881  |
# | come            |  -0.0367172  |
# | menu            |  -0.0397413  |
# | took            |  -0.0436442  |
# | event           |  -0.0474112  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | steaks         |     0.872218 |
# | ribeye         |     0.780679 |
# | rib-eye        |     0.753624 |
# | sirloin        |     0.753137 |
# | ribeyes        |     0.73076  |
# | steak-         |     0.726646 |
# | porterhouse    |     0.720404 |
# | steak.         |     0.711512 |
# | Steak          |     0.709836 |
# | rib-eyes       |     0.70738  |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Sinda           |     0.231912 |
# | Dimitrova       |     0.194577 |
# | Boyan           |     0.191589 |
# | Wikipedia.org.  |     0.191097 |
# | Petkova         |     0.188619 |
# | Evermind        |     0.185396 |
# | AD4             |     0.184899 |
# | TRACECA         |     0.184817 |
# | Ainur           |     0.184644 |
# | Kyosei          |     0.182161 |
#
# ----------------------------------------
#
# Analyzing word: full
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | friday         |     0.646812 |
# | half           |     0.567557 |
# | birthday       |     0.567194 |
# | roll           |     0.556244 |
# | deal           |     0.552321 |
# | end            |     0.542117 |
# | snack          |     0.536892 |
# | eat            |     0.536202 |
# | pack           |     0.533969 |
# | spring         |     0.504187 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | help            |   0.0958517  |
# | server          |   0.0419855  |
# | super           |   0.0284957  |
# | music           |   0.0201903  |
# | awesom          |   0.0176409  |
# | even            |   0.0142875  |
# | sushi           |  -0.00464993 |
# | seat            |  -0.0155185  |
# | staff           |  -0.0206938  |
# | food            |  -0.0333342  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | fulll          |     0.693878 |
# | FULL           |     0.635971 |
# | Full           |     0.617536 |
# | chock          |     0.614394 |
# | complete       |     0.586147 |
# | near-full      |     0.577344 |
# | chocked        |     0.549275 |
# | partial        |     0.530455 |
# | -full          |     0.514279 |
# | fledged        |     0.510177 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Hajela          |     0.234382 |
# | TNCompanies     |     0.222849 |
# | puffinus        |     0.218408 |
# | Fotedar         |     0.209055 |
# | へようこそ      |     0.204731 |
# | ph0rk           |     0.201333 |
# | موضوع           |     0.19983  |
# | Ser133          |     0.19852  |
# | Yastrow         |     0.197288 |
# | ARCompanies     |     0.195228 |
#
# ----------------------------------------
#
# Analyzing word: option
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | brew           |     0.652118 |
# | portion        |     0.620244 |
# | section        |     0.619196 |
# | cuban          |     0.582208 |
# | bean           |     0.58177  |
# | italian        |     0.570644 |
# | park           |     0.554354 |
# | local          |     0.552201 |
# | spot           |     0.550717 |
# | coffe          |     0.549347 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | went            |    0.0211252 |
# | appet           |    0.0148615 |
# | close           |   -0.0134295 |
# | pretti          |   -0.0204101 |
# | tri             |   -0.0215664 |
# | slow            |   -0.0218105 |
# | lunch           |   -0.0218175 |
# | actual          |   -0.0241323 |
# | took            |   -0.0255906 |
# | thursday        |   -0.0325194 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | options        |     0.718557 |
# | option.The     |     0.709092 |
# | option.This    |     0.705198 |
# | option.        |     0.638652 |
# | option.You     |     0.637848 |
# | option.But     |     0.637256 |
# | option.It      |     0.635082 |
# | choice         |     0.634777 |
# | option-        |     0.632716 |
# | option.If      |     0.630344 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Y.I.            |     0.240504 |
# | Z.W.            |     0.227694 |
# | USA7            |     0.225837 |
# | Wrung           |     0.213301 |
# | City9           |     0.213145 |
# | Pettin          |     0.212738 |
# | Bukk            |     0.210901 |
# | Somjit          |     0.210857 |
# | LEIB            |     0.210504 |
# | USA8            |     0.204366 |
#
# ----------------------------------------
#
# Analyzing word: chili
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | chees          |     0.724987 |
# | green          |     0.661056 |
# | know           |     0.639189 |
# | beef           |     0.58985  |
# | pickl          |     0.562655 |
# | onion          |     0.545209 |
# | chang          |     0.535386 |
# | sign           |     0.525495 |
# | soup           |     0.518785 |
# | busi           |     0.509259 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | cold            |  0.00478448  |
# | owner           |  0.0014425   |
# | call            |  0.000964617 |
# | hand            | -0.0109477   |
# | seat            | -0.0246649   |
# | need            | -0.0272724   |
# | tasti           | -0.0291933   |
# | everi           | -0.0317944   |
# | sushi           | -0.0325761   |
# | coffe           | -0.0334353   |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | chilis         |     0.764645 |
# | chili-         |     0.746653 |
# | chile          |     0.725451 |
# | chilli         |     0.71598  |
# | beanless       |     0.713311 |
# | Chili          |     0.704621 |
# | chipotle       |     0.704547 |
# | jalapeno       |     0.704236 |
# | chili.         |     0.703798 |
# | chilies        |     0.700276 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word    |   Similarity |
# |------------------|--------------|
# | Techlink         |     0.197554 |
# | DetailsPublisher |     0.197315 |
# | Natal            |     0.190043 |
# | SPHE             |     0.182723 |
# | Ayanda           |     0.182335 |
# | Lautenbach       |     0.181689 |
# | .Sony            |     0.178786 |
# | Synchronisation  |     0.171953 |
# | Serein           |     0.169449 |
# | Levien           |     0.168882 |
#
# ----------------------------------------
#
# Analyzing word: give
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | live           |     0.627869 |
# | qualiti        |     0.587056 |
# | section        |     0.578652 |
# | never          |     0.561592 |
# | loud           |     0.540756 |
# | style          |     0.534252 |
# | anyth          |     0.528307 |
# | keep           |     0.513089 |
# | authent        |     0.508488 |
# | staff          |     0.493284 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | beef            |    0.104035  |
# | much            |    0.0523703 |
# | appet           |    0.0491352 |
# | shrimp          |    0.031158  |
# | awesom          |   -0.0168955 |
# | came            |   -0.0246496 |
# | late            |   -0.0256389 |
# | taco            |   -0.0268709 |
# | amaz            |   -0.0296985 |
# | night           |   -0.0390206 |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | gives          |     0.717501 |
# | giving         |     0.699898 |
# | gave           |     0.695683 |
# | Give           |     0.67025  |
# | provide        |     0.627041 |
# | get            |     0.624038 |
# | gve            |     0.616658 |
# | want           |     0.616529 |
# | take           |     0.609153 |
# | ask            |     0.585747 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | 2001.1          |     0.239208 |
# | 2016-03         |     0.233807 |
# | --FSA           |     0.233515 |
# | 2015-05         |     0.231197 |
# | 2015-06         |     0.227172 |
# | 2017-06         |     0.225821 |
# | 2014-08         |     0.223618 |
# | Adult-onset     |     0.220582 |
# | FLThursday      |     0.219951 |
# | Internecine     |     0.217694 |
#
# ----------------------------------------
#
# Analyzing word: wish
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | sure           |     0.700026 |
# | show           |     0.644886 |
# | busi           |     0.631432 |
# | keep           |     0.629938 |
# | ahead          |     0.614034 |
# | visit          |     0.58504  |
# | use            |     0.577776 |
# | charg          |     0.56215  |
# | beauti         |     0.544103 |
# | everyth        |     0.543181 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | food            |   0.00675018 |
# | well            |  -0.00170429 |
# | best            |  -0.00634999 |
# | pizza           |  -0.0395533  |
# | cuban           |  -0.043016   |
# | half            |  -0.0558427  |
# | coffe           |  -0.0570862  |
# | tast            |  -0.0708379  |
# | must            |  -0.0798704  |
# | select          |  -0.0864483  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | wished         |     0.753125 |
# | wishing        |     0.701217 |
# | wishes         |     0.632715 |
# | want           |     0.628685 |
# | hope           |     0.615534 |
# | wishe          |     0.614832 |
# | whish          |     0.594463 |
# | you            |     0.593283 |
# | wish.I         |     0.584423 |
# | would          |     0.576273 |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | Science13       |     0.238892 |
# | Erosional       |     0.229682 |
# | Science17       |     0.223999 |
# | 1.714           |     0.212291 |
# | Science10       |     0.210441 |
# | Measuring       |     0.209195 |
# | 'FCW            |     0.208305 |
# | production6     |     0.206855 |
# | Tartak          |     0.206757 |
# | February-1      |     0.206378 |
#
# ----------------------------------------
#
# Analyzing word: tri
#
# Custom-trained FastText model results:
# Top 10 similar words (custom model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | actual         |     0.76416  |
# | went           |     0.648643 |
# | miss           |     0.620727 |
# | street         |     0.588521 |
# | peopl          |     0.581277 |
# | super          |     0.573225 |
# | dessert        |     0.56972  |
# | margarita      |     0.540022 |
# | help           |     0.528226 |
# | know           |     0.524579 |
#
# Top 10 opposite words (custom model):
# | Opposite Word   |   Similarity |
# |-----------------|--------------|
# | come            |   0.0650666  |
# | brunch          |   0.0440889  |
# | coffe           |   0.043477   |
# | pizza           |   0.0263267  |
# | mani            |   0.0118709  |
# | alway           |   0.00726327 |
# | game            |  -0.0188775  |
# | option          |  -0.0215664  |
# | littl           |  -0.0299759  |
# | cheap           |  -0.0334836  |
#
# Top 10 similar words (pre-trained model):
# | Similar Word   |   Similarity |
# |----------------|--------------|
# | tri-           |     0.62988  |
# | Tri            |     0.609636 |
# | tri.           |     0.576011 |
# | triathlon      |     0.562205 |
# | Tri-           |     0.558308 |
# | duathlon       |     0.536708 |
# | tris           |     0.533268 |
# | triathalon     |     0.522689 |
# | half-iron      |     0.50119  |
# | ironman        |     0.49964  |
#
# Top 10 opposite words (pre-trained model):
# | Opposite Word       |   Similarity |
# |---------------------|--------------|
# | University.Rooms    |     0.215691 |
# | Conversing          |     0.18825  |
# | empty.View          |     0.188074 |
# | Infringers          |     0.18668  |
# | Citing              |     0.185348 |
# | BooksBrand          |     0.184734 |
# | ToyTalk             |     0.183512 |
# | Infringements       |     0.182614 |
# | Emolument           |     0.182134 |
# | information.Returns |     0.181288 |
#
# ----------------------------------------

# %%
# import random
# tokens = [re.sub(r'[^a-zA-Z\s]', ' ', token) for token in subset_tips]
# tokenized_tips = [nltk.word_tokenize(sentence) for sentence in tokens]
# tokenized_tips = [[token.lower() for token in sentence if token.isalpha() and len(token) > 3] for sentence in tokenized_tips]

# # Remove punctuation


# # Now you can randomly sample sentences from tokenized_tips
# sentences_to_sample = 10  # Number of sentences you want to sample
# random_sentences = random.sample(tokenized_tips, sentences_to_sample)


# fasttext_results = {}
# for sentence in random_sentences:
#     for word in sentence:
#         similar_words, negative_words = test(model, word)
#         fasttext_results[word] = (similar_words, negative_words)

# %%
# pretrained_results = {}
# for sentence in random_sentences:
#     for word in sentence:
#         similar_words = model.wv.most_similar_cosmul(word, topn=10)
#         negative_words = model.wv.most_similar_cosmul(positive=[word], negative=[word], topn=10)  
#         pretrained_results[word] = (similar_words, negative_words)

# %%
# pretrained_results = {}
# for sentence in random_sentences:
#     for word in sentence:
#         similar_words = model.wv.most_similar_cosmul(word, topn=10)
#         negative_words = model.wv.most_similar_cosmul(positive=['random'], negative=[word], topn=10)  # Change 'random' to any word not related to the context
#         pretrained_results[word] = (similar_words, negative_words)
